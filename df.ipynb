# %%
import pandas as pd

# %%
# Get all the csv file names in the current directory starting with "emails"
import glob
csv_files = glob.glob("emails/themanifest*.csv")
len(csv_files)
# Out:
# 556

# %%
# Concatenate all the csv files into one dataframe

df = pd.concat([pd.read_csv(f) for f in csv_files])
df
# Out:
#          company_name                                                url  \
# 0           Bee Techy  https://beetechy.com/?utm_campaign=directory&u...
# 1           Entrision  https://entrision.com?utm_campaign=directory&u...
# 2       Relish Studio  https://relishstudio.com/?utm_campaign=directo...
# 3            Dibutech  https://www.dibutech.com/?utm_campaign=directo...
# 4               Viget  https://www.viget.com/?utm_campaign=directory&...
# ..                ...                                                ...
# 59  Clay Pot Creative  https://www.claypotcreative.com/about/graphic-...
# 60  Clay Pot Creative     https://www.claypotcreative.com/about/services
# 61  Clay Pot Creative  https://www.claypotcreative.com/about/website-...
# 62  Clay Pot Creative  https://www.claypotcreative.com/about/marketin...
# 63  Clay Pot Creative     https://www.claypotcreative.com/about/branding
#
#                                   emails country
# 0                   contact@beetechy.com      us
# 1                                    NaN      us
# 2                  info@relishstudio.com      us
# 3   sales@dibutech.com,info@dibutech.com      us
# 4                        hello@viget.com      us
# ..                                   ...     ...
# 59                                   NaN      us
# 60                                   NaN      us
# 61                                   NaN      us
# 62                                   NaN      us
# 63                                   NaN      us
#
# [29001 rows x 4 columns]

# %%
# drop duplicate rows
df = df.drop_duplicates()
df
# Out:
#          company_name                                                url  \
# 0           Bee Techy  https://beetechy.com/?utm_campaign=directory&u...
# 1           Entrision  https://entrision.com?utm_campaign=directory&u...
# 2       Relish Studio  https://relishstudio.com/?utm_campaign=directo...
# 3            Dibutech  https://www.dibutech.com/?utm_campaign=directo...
# 4               Viget  https://www.viget.com/?utm_campaign=directory&...
# ..                ...                                                ...
# 59  Clay Pot Creative  https://www.claypotcreative.com/about/graphic-...
# 60  Clay Pot Creative     https://www.claypotcreative.com/about/services
# 61  Clay Pot Creative  https://www.claypotcreative.com/about/website-...
# 62  Clay Pot Creative  https://www.claypotcreative.com/about/marketin...
# 63  Clay Pot Creative     https://www.claypotcreative.com/about/branding
#
#                                   emails country
# 0                   contact@beetechy.com      us
# 1                                    NaN      us
# 2                  info@relishstudio.com      us
# 3   sales@dibutech.com,info@dibutech.com      us
# 4                        hello@viget.com      us
# ..                                   ...     ...
# 59                                   NaN      us
# 60                                   NaN      us
# 61                                   NaN      us
# 62                                   NaN      us
# 63                                   NaN      us
#
# [28806 rows x 4 columns]

# %%
df.to_csv("emails/emails_full.csv", index=False)

# %%
df = pd.read_csv("emails/emails_full.csv")

# %%
df.isnull().sum()
# Out:
# company_name        0
# url                 0
# emails          12830
# country             0
# dtype: int64

# %%
# drop rows wiith missing email addresses
df = df.dropna(subset=["emails"])
df
# Out:
#                  company_name  \
# 0                   Bee Techy
# 2               Relish Studio
# 3                    Dibutech
# 4                       Viget
# 6        Design Genious Corp.
# ...                       ...
# 28795       Clay Pot Creative
# 28796  Sabre Digital Creative
# 28797  Sabre Digital Creative
# 28798            Inroads, LLC
# 28800  Sabre Digital Creative
#
#                                                      url  \
# 0      https://beetechy.com/?utm_campaign=directory&u...
# 2      https://relishstudio.com/?utm_campaign=directo...
# 3      https://www.dibutech.com/?utm_campaign=directo...
# 4      https://www.viget.com/?utm_campaign=directory&...
# 6      https://designgenious.com/?utm_campaign=direct...
# ...                                                  ...
# 28795  https://www.claypotcreative.com/contact/contac...
# 28796  https://www.sabredigitalmarketing.com/?utm_cam...
# 28797       https://www.sabredigitalmarketing.com/about/
# 28798                  https://www.inroads.us/about.html
# 28800     https://www.sabredigitalmarketing.com/contact/
#
#                                      emails country
# 0                      contact@beetechy.com      us
# 2                     info@relishstudio.com      us
# 3      sales@dibutech.com,info@dibutech.com      us
# 4                           hello@viget.com      us
# 6                      cs@designgenious.com      us
# ...                                     ...     ...
# 28795              jobs@claypotcreative.com      us
# 28796    reachout@sabredigitalmarketing.com      us
# 28797    reachout@sabredigitalmarketing.com      us
# 28798                       info@inroads.us      us
# 28800    reachout@sabredigitalmarketing.com      us
#
# [15976 rows x 4 columns]

# %%
df.shape
# Out:
# (15976, 4)

# %%
df.nunique()
# Out:
# company_name     6892
# url             15756
# emails           8279
# country             3
# dtype: int64

# %%
# split emails into separate rows
df = df.assign(emails=df.emails.str.split(",")).explode("emails")
df
# Out:
#                  company_name  \
# 0                   Bee Techy
# 2               Relish Studio
# 3                    Dibutech
# 3                    Dibutech
# 4                       Viget
# ...                       ...
# 28795       Clay Pot Creative
# 28796  Sabre Digital Creative
# 28797  Sabre Digital Creative
# 28798            Inroads, LLC
# 28800  Sabre Digital Creative
#
#                                                      url  \
# 0      https://beetechy.com/?utm_campaign=directory&u...
# 2      https://relishstudio.com/?utm_campaign=directo...
# 3      https://www.dibutech.com/?utm_campaign=directo...
# 3      https://www.dibutech.com/?utm_campaign=directo...
# 4      https://www.viget.com/?utm_campaign=directory&...
# ...                                                  ...
# 28795  https://www.claypotcreative.com/contact/contac...
# 28796  https://www.sabredigitalmarketing.com/?utm_cam...
# 28797       https://www.sabredigitalmarketing.com/about/
# 28798                  https://www.inroads.us/about.html
# 28800     https://www.sabredigitalmarketing.com/contact/
#
#                                    emails country
# 0                    contact@beetechy.com      us
# 2                   info@relishstudio.com      us
# 3                      sales@dibutech.com      us
# 3                       info@dibutech.com      us
# 4                         hello@viget.com      us
# ...                                   ...     ...
# 28795            jobs@claypotcreative.com      us
# 28796  reachout@sabredigitalmarketing.com      us
# 28797  reachout@sabredigitalmarketing.com      us
# 28798                     info@inroads.us      us
# 28800  reachout@sabredigitalmarketing.com      us
#
# [23314 rows x 4 columns]

# %%
# drop duplicate emails
df = df.drop_duplicates(subset=["emails"])
df
# Out:
#                        company_name  \
# 0                         Bee Techy
# 2                     Relish Studio
# 3                          Dibutech
# 3                          Dibutech
# 4                             Viget
# ...                             ...
# 28783  In Their Face Marketing, LLC
# 28787                 Studio Fabric
# 28792                  Inroads, LLC
# 28793                  Inroads, LLC
# 28795             Clay Pot Creative
#
#                                                      url  \
# 0      https://beetechy.com/?utm_campaign=directory&u...
# 2      https://relishstudio.com/?utm_campaign=directo...
# 3      https://www.dibutech.com/?utm_campaign=directo...
# 3      https://www.dibutech.com/?utm_campaign=directo...
# 4      https://www.viget.com/?utm_campaign=directory&...
# ...                                                  ...
# 28783                    https://ntheirface.com/contact/
# 28787  https://studiofabric.com/?utm_campaign=directo...
# 28792  https://www.inroads.us/?utm_campaign=directory...
# 28793                https://www.inroads.us/contact.html
# 28795  https://www.claypotcreative.com/contact/contac...
#
#                          emails country
# 0          contact@beetechy.com      us
# 2         info@relishstudio.com      us
# 3            sales@dibutech.com      us
# 3             info@dibutech.com      us
# 4               hello@viget.com      us
# ...                         ...     ...
# 28783     hustle@ntheirface.com      us
# 28787     Hola@StudioFabric.com      us
# 28792           info@inroads.us      us
# 28793          info@inroads.com      us
# 28795  jobs@claypotcreative.com      us
#
# [11432 rows x 4 columns]

# %%
# a function to get domain from url
from urllib.parse import urlparse

def get_domain(url):
    if url:
        parsed_uri = urlparse(url)
        domain = parsed_uri.netloc
        return domain
    else:
        return url

df['domain'] = df['url'].apply(get_domain)
df
# Out:
# /tmp/ipykernel_25211/2045235552.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['domain'] = df['url'].apply(get_domain)
#                        company_name  \
# 0                         Bee Techy
# 2                     Relish Studio
# 3                          Dibutech
# 3                          Dibutech
# 4                             Viget
# ...                             ...
# 28783  In Their Face Marketing, LLC
# 28787                 Studio Fabric
# 28792                  Inroads, LLC
# 28793                  Inroads, LLC
# 28795             Clay Pot Creative
#
#                                                      url  \
# 0      https://beetechy.com/?utm_campaign=directory&u...
# 2      https://relishstudio.com/?utm_campaign=directo...
# 3      https://www.dibutech.com/?utm_campaign=directo...
# 3      https://www.dibutech.com/?utm_campaign=directo...
# 4      https://www.viget.com/?utm_campaign=directory&...
# ...                                                  ...
# 28783                    https://ntheirface.com/contact/
# 28787  https://studiofabric.com/?utm_campaign=directo...
# 28792  https://www.inroads.us/?utm_campaign=directory...
# 28793                https://www.inroads.us/contact.html
# 28795  https://www.claypotcreative.com/contact/contac...
#
#                          emails country                   domain
# 0          contact@beetechy.com      us             beetechy.com
# 2         info@relishstudio.com      us         relishstudio.com
# 3            sales@dibutech.com      us         www.dibutech.com
# 3             info@dibutech.com      us         www.dibutech.com
# 4               hello@viget.com      us            www.viget.com
# ...                         ...     ...                      ...
# 28783     hustle@ntheirface.com      us           ntheirface.com
# 28787     Hola@StudioFabric.com      us         studiofabric.com
# 28792           info@inroads.us      us           www.inroads.us
# 28793          info@inroads.com      us           www.inroads.us
# 28795  jobs@claypotcreative.com      us  www.claypotcreative.com
#
# [11432 rows x 5 columns]

# %%
import tldextract

def get_domain_without_subdomain(url):
    extracted = tldextract.extract(url)
    return "{}.{}".format(extracted.domain, extracted.suffix)

df['domain_tld'] = df['url'].apply(get_domain_without_subdomain)
df
# Out:
# /tmp/ipykernel_25211/1427031664.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['domain_tld'] = df['url'].apply(get_domain_without_subdomain)
#                        company_name  \
# 0                         Bee Techy
# 2                     Relish Studio
# 3                          Dibutech
# 3                          Dibutech
# 4                             Viget
# ...                             ...
# 28783  In Their Face Marketing, LLC
# 28787                 Studio Fabric
# 28792                  Inroads, LLC
# 28793                  Inroads, LLC
# 28795             Clay Pot Creative
#
#                                                      url  \
# 0      https://beetechy.com/?utm_campaign=directory&u...
# 2      https://relishstudio.com/?utm_campaign=directo...
# 3      https://www.dibutech.com/?utm_campaign=directo...
# 3      https://www.dibutech.com/?utm_campaign=directo...
# 4      https://www.viget.com/?utm_campaign=directory&...
# ...                                                  ...
# 28783                    https://ntheirface.com/contact/
# 28787  https://studiofabric.com/?utm_campaign=directo...
# 28792  https://www.inroads.us/?utm_campaign=directory...
# 28793                https://www.inroads.us/contact.html
# 28795  https://www.claypotcreative.com/contact/contac...
#
#                          emails country                   domain  \
# 0          contact@beetechy.com      us             beetechy.com
# 2         info@relishstudio.com      us         relishstudio.com
# 3            sales@dibutech.com      us         www.dibutech.com
# 3             info@dibutech.com      us         www.dibutech.com
# 4               hello@viget.com      us            www.viget.com
# ...                         ...     ...                      ...
# 28783     hustle@ntheirface.com      us           ntheirface.com
# 28787     Hola@StudioFabric.com      us         studiofabric.com
# 28792           info@inroads.us      us           www.inroads.us
# 28793          info@inroads.com      us           www.inroads.us
# 28795  jobs@claypotcreative.com      us  www.claypotcreative.com
#
#                 domain_tld
# 0             beetechy.com
# 2         relishstudio.com
# 3             dibutech.com
# 3             dibutech.com
# 4                viget.com
# ...                    ...
# 28783       ntheirface.com
# 28787     studiofabric.com
# 28792           inroads.us
# 28793           inroads.us
# 28795  claypotcreative.com
#
# [11432 rows x 6 columns]

# %%
def get_domain_from_email(email):
    try:
        return email.split('@')[1]
    except IndexError:
        return None
    
df.loc[:,'domain_email'] = df['emails'].apply(get_domain_from_email)
df
# Out:
# /tmp/ipykernel_25211/2881094048.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'domain_email'] = df['emails'].apply(get_domain_from_email)
#                        company_name  \
# 0                         Bee Techy
# 2                     Relish Studio
# 3                          Dibutech
# 3                          Dibutech
# 4                             Viget
# ...                             ...
# 28783  In Their Face Marketing, LLC
# 28787                 Studio Fabric
# 28792                  Inroads, LLC
# 28793                  Inroads, LLC
# 28795             Clay Pot Creative
#
#                                                      url  \
# 0      https://beetechy.com/?utm_campaign=directory&u...
# 2      https://relishstudio.com/?utm_campaign=directo...
# 3      https://www.dibutech.com/?utm_campaign=directo...
# 3      https://www.dibutech.com/?utm_campaign=directo...
# 4      https://www.viget.com/?utm_campaign=directory&...
# ...                                                  ...
# 28783                    https://ntheirface.com/contact/
# 28787  https://studiofabric.com/?utm_campaign=directo...
# 28792  https://www.inroads.us/?utm_campaign=directory...
# 28793                https://www.inroads.us/contact.html
# 28795  https://www.claypotcreative.com/contact/contac...
#
#                          emails country                   domain  \
# 0          contact@beetechy.com      us             beetechy.com
# 2         info@relishstudio.com      us         relishstudio.com
# 3            sales@dibutech.com      us         www.dibutech.com
# 3             info@dibutech.com      us         www.dibutech.com
# 4               hello@viget.com      us            www.viget.com
# ...                         ...     ...                      ...
# 28783     hustle@ntheirface.com      us           ntheirface.com
# 28787     Hola@StudioFabric.com      us         studiofabric.com
# 28792           info@inroads.us      us           www.inroads.us
# 28793          info@inroads.com      us           www.inroads.us
# 28795  jobs@claypotcreative.com      us  www.claypotcreative.com
#
#                 domain_tld         domain_email
# 0             beetechy.com         beetechy.com
# 2         relishstudio.com     relishstudio.com
# 3             dibutech.com         dibutech.com
# 3             dibutech.com         dibutech.com
# 4                viget.com            viget.com
# ...                    ...                  ...
# 28783       ntheirface.com       ntheirface.com
# 28787     studiofabric.com     StudioFabric.com
# 28792           inroads.us           inroads.us
# 28793           inroads.us          inroads.com
# 28795  claypotcreative.com  claypotcreative.com
#
# [11432 rows x 7 columns]

# %%
# keep only rows where domain_email and domain_tld are the same
df = df[df['domain_email'] == df['domain_tld']]
df
# Out:
#                        company_name  \
# 0                         Bee Techy
# 2                     Relish Studio
# 3                          Dibutech
# 3                          Dibutech
# 4                             Viget
# ...                             ...
# 28771               BrandQuery, LLC
# 28777      SideCar Public Relations
# 28783  In Their Face Marketing, LLC
# 28792                  Inroads, LLC
# 28795             Clay Pot Creative
#
#                                                      url  \
# 0      https://beetechy.com/?utm_campaign=directory&u...
# 2      https://relishstudio.com/?utm_campaign=directo...
# 3      https://www.dibutech.com/?utm_campaign=directo...
# 3      https://www.dibutech.com/?utm_campaign=directo...
# 4      https://www.viget.com/?utm_campaign=directory&...
# ...                                                  ...
# 28771                    https://brandquery.com/about-2/
# 28777                     https://sidecarpr.com/contact/
# 28783                    https://ntheirface.com/contact/
# 28792  https://www.inroads.us/?utm_campaign=directory...
# 28795  https://www.claypotcreative.com/contact/contac...
#
#                          emails country                   domain  \
# 0          contact@beetechy.com      us             beetechy.com
# 2         info@relishstudio.com      us         relishstudio.com
# 3            sales@dibutech.com      us         www.dibutech.com
# 3             info@dibutech.com      us         www.dibutech.com
# 4               hello@viget.com      us            www.viget.com
# ...                         ...     ...                      ...
# 28771    jbeamer@brandquery.com      us           brandquery.com
# 28777       hello@sidecarpr.com      us            sidecarpr.com
# 28783     hustle@ntheirface.com      us           ntheirface.com
# 28792           info@inroads.us      us           www.inroads.us
# 28795  jobs@claypotcreative.com      us  www.claypotcreative.com
#
#                 domain_tld         domain_email
# 0             beetechy.com         beetechy.com
# 2         relishstudio.com     relishstudio.com
# 3             dibutech.com         dibutech.com
# 3             dibutech.com         dibutech.com
# 4                viget.com            viget.com
# ...                    ...                  ...
# 28771       brandquery.com       brandquery.com
# 28777        sidecarpr.com        sidecarpr.com
# 28783       ntheirface.com       ntheirface.com
# 28792           inroads.us           inroads.us
# 28795  claypotcreative.com  claypotcreative.com
#
# [9021 rows x 7 columns]

# %%
# drop domain_email and domain_tld columns
df = df.drop(columns=['domain_email', 'domain_tld'])
df
# Out:
#                        company_name  \
# 0                         Bee Techy
# 2                     Relish Studio
# 3                          Dibutech
# 3                          Dibutech
# 4                             Viget
# ...                             ...
# 28771               BrandQuery, LLC
# 28777      SideCar Public Relations
# 28783  In Their Face Marketing, LLC
# 28792                  Inroads, LLC
# 28795             Clay Pot Creative
#
#                                                      url  \
# 0      https://beetechy.com/?utm_campaign=directory&u...
# 2      https://relishstudio.com/?utm_campaign=directo...
# 3      https://www.dibutech.com/?utm_campaign=directo...
# 3      https://www.dibutech.com/?utm_campaign=directo...
# 4      https://www.viget.com/?utm_campaign=directory&...
# ...                                                  ...
# 28771                    https://brandquery.com/about-2/
# 28777                     https://sidecarpr.com/contact/
# 28783                    https://ntheirface.com/contact/
# 28792  https://www.inroads.us/?utm_campaign=directory...
# 28795  https://www.claypotcreative.com/contact/contac...
#
#                          emails country                   domain
# 0          contact@beetechy.com      us             beetechy.com
# 2         info@relishstudio.com      us         relishstudio.com
# 3            sales@dibutech.com      us         www.dibutech.com
# 3             info@dibutech.com      us         www.dibutech.com
# 4               hello@viget.com      us            www.viget.com
# ...                         ...     ...                      ...
# 28771    jbeamer@brandquery.com      us           brandquery.com
# 28777       hello@sidecarpr.com      us            sidecarpr.com
# 28783     hustle@ntheirface.com      us           ntheirface.com
# 28792           info@inroads.us      us           www.inroads.us
# 28795  jobs@claypotcreative.com      us  www.claypotcreative.com
#
# [9021 rows x 5 columns]

# %%
df.nunique()
# Out:
# company_name    6015
# url             6749
# emails          9021
# country            2
# domain          6049
# dtype: int64

# %%
df.to_csv("emails/emails_clean.csv", index=False)

# %%
# emails starting with numbers
df[df['emails'].str.contains(r'^\d')]
# Out:
# Empty DataFrame
# Columns: [company_name, url, emails, country, domain]
# Index: []

# %%
# count of rows having unique country values
df.groupby('country').nunique()
# Out:
#          company_name   url  emails  domain
# country
# uk               1382  1543    2010    1387
# us               4636  5206    7011    4662

# %%
extracted = tldextract.extract('https://www.abcxyz.studio')
print(extracted.domain)
print(extracted.suffix)
# Out:
# abcxyz
# studio

# %%
df.groupby
# Out:
# <bound method DataFrame.groupby of                                        company_name  \
# 0                Maco Software (Shanghai) Co., Ltd.
# 4                              The ComRatings Group
# 5             Shenzhen Juexing Technology Co., Ltd.
# 6                  USTC Sinovate Software Co., Ltd.
# 8      Beijing SBR Information Technology Co., Ltd.
# ...                                             ...
# 56026                                         A1FED
# 56029                      DELTA Computer Solutions
# 56034                                   NeevSys Inc
# 56035                             TecPort Solutions
# 56035                             TecPort Solutions
#
#                                                      url  \
# 0      http://www.macochart.com/?utm_campaign=directo...
# 4      https://www.comratings.com/?utm_campaign=direc...
# 5      http://www.juexingkeji.net/?utm_campaign=direc...
# 6      http://www.kdgcsoft.com/?utm_campaign=director...
# 8      https://www.sbr-info.com/?utm_campaign=directo...
# ...                                                  ...
# 56026                  https://www.a1fed.com/contact-us/
# 56029       http://deltacs.com/index.php5?page=contactUs
# 56034  https://neevsys.com/?utm_campaign=directory&ut...
# 56035      https://tecportsolutions.com/contact-tecport/
# 56035      https://tecportsolutions.com/contact-tecport/
#
#                                           emails                domain  \
# 0                          service@macochart.com     www.macochart.com
# 4                            info@comratings.com    www.comratings.com
# 5                        business@juexingkeji.cn   www.juexingkeji.net
# 6                           service@ustcinfo.com      www.kdgcsoft.com
# 8                           support@sbr-info.com      www.sbr-info.com
# ...                                          ...                   ...
# 56026                        inquiries@a1fed.com         www.a1fed.com
# 56029                           info@deltacs.com           deltacs.com
# 56034                           info@neevsys.com           neevsys.com
# 56035           information@tecportsolutions.com  tecportsolutions.com
# 56035  carmine.taglialatela@tecportsolutions.com  tecportsolutions.com
#
#                  domain_tld
# 0             macochart.com
# 4            comratings.com
# 5           juexingkeji.net
# 6              kdgcsoft.com
# 8              sbr-info.com
# ...                     ...
# 56026             a1fed.com
# 56029           deltacs.com
# 56034           neevsys.com
# 56035  tecportsolutions.com
# 56035  tecportsolutions.com
#
# [27041 rows x 5 columns]>
